# %% [markdown]
# # neural networks in python and numpy!

# %% [markdown]
# Let's look at some of the more common neural network concepts and explore the different pros/cons of using each. First, we are going to need some datasets! Let's import numpy and sklearn.

# %%
import numpy as np
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from matplotlib import pyplot as plt

# set this for repeatability (so my comments on the performance make sense!)
np.random.seed(10)

plt.rcParams["figure.figsize"] = (16, 10)

# %% [markdown]
# ScienceKit Learn (sklearn) has some great daatsets built in! We can define some functions for loading datasets!

# %%
def get_dataset_iris(test_split=0.20):
    '''returns (x_train, y_train), (x_test, y_test)'''
    dataset = datasets.load_iris()
    X, y = dataset.data, dataset.target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_split)
    y_train = one_hot(y_train, 3)
    y_test = one_hot(y_test, 3)
    return (X_train, y_train), (X_test, y_test)

def get_dataset_digits(test_split=0.20):
    '''returns (x_train, y_train), (x_test, y_test)'''
    dataset = datasets.load_digits()
    X, y = dataset.data, dataset.target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_split)
    y_train = one_hot(y_train, 10)
    y_test = one_hot(y_test, 10)
    return (X_train, y_train), (X_test, y_test)

def get_dataset_wine(test_split=0.20):
    '''returns (x_train, y_train), (x_test, y_test)'''
    dataset = datasets.load_wine()
    X, y = dataset.data, dataset.target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_split)
    y_train = one_hot(y_train, 3)
    y_test = one_hot(y_test, 3)
    return (X_train, y_train), (X_test, y_test)

def one_hot(x, classes):
    '''returns onehot encoded vector for each item in x'''
    ret = []
    for value in x:
        temp = [0. for _ in range(classes)]
        temp[int(value)] = 1.
        ret.append(temp)
    return np.array(ret)

# %% [markdown]
# The above functions should be pretty self explainatory, we are loading the datasets and onehot encoding the y (label) values into vectors. This is strictly necesarry for binary classifiers however, all of the datasets have atleast 3 or more different classes.

# %% [markdown]
# Let's use our new functions to load up the iris dataset!

# %%
# load the iris dataset
(x_train, y_train), (x_test, y_test) = get_dataset_iris()

print('x_train[0]:')
print(x_train[0])

print('y_train[0]:')
print(y_train[0])
# Out:
# x_train[0]:
# [6.6 2.9 4.6 1.3]
# y_train[0]:
# [0. 1. 0.]

# %% [markdown]
# Now we have our data loaded up lets look at defining some activation functions for our network to use!

# %%
# activation functions and derivatives
def ReLU(x, deriv=False):
    '''returns the Rectified Linear Unit (or derivative) x'''
    if deriv:
        return 1. * (x > 0)
    else:
        x = np.clip(x, -700, 700)
        return x * (x > 0)

def leaky_ReLU(x, deriv=False, alpha=0.1):
    '''returns the leaky Rectified Linear Unit (or derivative) x'''
    if deriv:
        return 1. * (x > 0) + alpha * (x <= 0)
    else:
        x = np.clip(x, -700, 700)
        return x * (x > 0) + x * alpha * (x <= 0)

def ELU(x, deriv=False, alpha=1.0):
    '''returns the Exponential Linear Unit (or derivative) x'''
    if deriv:
        return 1. * (x > 0) + alpha * (np.exp(x)-1) * (x <= 0)
    else:
        x = np.clip(x, -700, 700)
        return x * (x > 0) + alpha * (np.exp(x)-1) * (x <= 0)

def sigmoid(x, deriv=False):
    '''returns the sigmoid (or derivative) x'''
    if deriv:
        return sigmoid(x) * (1 - sigmoid(x))
    else:
        x = np.clip(x, -700, 700)
        return 1 / (1 + np.exp(-x))

def tanh(x, deriv=False):
    '''returns the hyperbolic tangent (or derivative) x'''
    if deriv:
        return 1.0 - (np.tanh(x) ** 2)
    else:
        return np.tanh(x)

# %% [markdown]
# Now we have our activation functions lets define our loss function, we will be using a very simple loss function aptly named "absolute loss".

# %%
def loss_absolute(y, y_hat):
    return y - y_hat

# %% [markdown]
# Let's define one last thing before we build our neural network. A method for spliting the training data batches will allow us to do Batch Gradient Descent. Rather than training our netowkr on one value of x and y at a time, we will be sending through batches! This allows our network to perform much better on most CPU's and also smooths the gradient allowing a "simpler" (and often quicker) descent to the minima!

# %%
def split_to_minibatch(z, batch_size=32):
    z_length = len(z)
    current_batch_size = batch_size
    batch_split_points = []
    while current_batch_size < z_length:
        batch_split_points.append(current_batch_size)
        current_batch_size += batch_size
    return np.split(z, batch_split_points)

# %% [markdown]
# It's time to build our neural network! we are going to implement an "N-layered Neural Netork", let's define our network as a python class!

# %%
class NNN(object):
    """An N-layered neural network"""
    def __init__(self, inputs, weights, outputs, alpha=0.0001, mu=0.9, momentum=False):
        self.inputs = inputs
        self.outputs = outputs
        self._ALPHA = alpha
        self._MU = mu
        self._num_of_weights = len(weights)
        self._LAYER_DEFS = {}
        self.WEIGHT_DATA = {}
        self.BIAS_DATA = {}
        self.enable_momentum = momentum
        if self.enable_momentum:
            self.VELOCITY_DATA = {}
        self.LAYER_FUNC = {}
        self.LAYERS = {}
        for i in range(self._num_of_weights):
            #(in, out, nonlin)
            self._LAYER_DEFS[i] = {'in': weights[i][0],
                                   'out': weights[i][1],
                                   'nonlin': weights[i][2]}
        self._init_layers()
    
    def _init_layers(self):
        for i in range(self._num_of_weights):
            _in = self._LAYER_DEFS[i]['in']
            _out = self._LAYER_DEFS[i]['out']
            _nonlin = self._LAYER_DEFS[i]['nonlin']
            self.WEIGHT_DATA[i] = 2 * np.random.random_sample((_in, _out)) - 1
            self.BIAS_DATA[i] = np.full((1,_out), 0.0)
            if self.enable_momentum:
                self.VELOCITY_DATA[i] = np.zeros(_out)
            self.LAYER_FUNC[i] = _nonlin

    def forward_layer(self, prev_layer, next_layer, bias_values, nonlin):
        """Does the actual calcs between layers :)"""
        ret = nonlin(np.dot(prev_layer, next_layer)+bias_values)
        return ret
    
    def backward_layer(self, w, z, act, prev_delta):
        w_error = prev_delta.dot(w.T)
        cur_delta = w_error * act(z, deriv=True)
        return cur_delta

    def backprop_sgd(self, w, z, act, prev_delta, bias):
        cur_delta = self.backward_layer(w, z, act, prev_delta)
        w += self._ALPHA * z.T.dot(prev_delta)
        bias += -self._ALPHA * np.sum(prev_delta, axis=0, keepdims=True)
        return cur_delta

    def backprop_momentum(self, w, z, act, prev_delta, bias, v):
        cur_delta = self.backward_layer(w, z, act, prev_delta)
        v = self._MU * v + z.T.dot(prev_delta)
        w += self._ALPHA * v
        bias += -self._ALPHA * np.sum(prev_delta, axis=0, keepdims=True)
        return cur_delta
    
    def fit(self, X_in, Y_in, train_loops=100, batch_size=32, quiet=False):
        loss_array = []
        for j in range(train_loops):
            X_in, Y_in = shuffle(X_in, Y_in)
            x_batches = split_to_minibatch(X_in, batch_size)
            y_batches = split_to_minibatch(Y_in, batch_size)
            epoch_loss = 0
            for x, y in zip(x_batches, y_batches):
                # set up layers
                prev_layer = self.LAYERS[0] = x
                for i in range(self._num_of_weights):
                    current_layer = self.forward_layer(prev_layer, 
                                                       self.WEIGHT_DATA[i],
                                                       self.BIAS_DATA[i], 
                                                       self.LAYER_FUNC[i])
                    self.LAYERS[i+1] = current_layer
                    prev_layer = current_layer
                last_layer = current_layer
    
                # calculate errors
                error = loss_absolute(y, last_layer)
                nonlin = self.LAYER_FUNC[self._num_of_weights - 1]
                delta = error * nonlin(last_layer, deriv=True)
    
                epoch_loss += np.sum(abs(error))
    
                prev_delta = delta
                for i in reversed(range(self._num_of_weights)):
                    if self.enable_momentum:
                        prev_delta = self.backprop_momentum(self.WEIGHT_DATA[i],
                                                            self.LAYERS[i], 
                                                            self.LAYER_FUNC[i], 
                                                            prev_delta, 
                                                            self.BIAS_DATA[i],
                                                            self.VELOCITY_DATA[i])
                    else:
                        prev_delta = self.backprop_sgd(self.WEIGHT_DATA[i],
                                                       self.LAYERS[i], 
                                                       self.LAYER_FUNC[i], 
                                                       prev_delta, 
                                                       self.BIAS_DATA[i])
            
            loss_array.append(epoch_loss)
            
            if not quiet:
                if (j % (train_loops/10)) == 0:             
                    print("-"*32)
                    print("loop: {}".format(j))
                    print("-"*32)
                    print("Guess (rounded): \n{}".format(np.round(last_layer[0], 3)))
                    print("Actual: \n{}".format(np.round(y[0], 3)))
                    print("-"*32, '\n')

        return loss_array
        
    def evaluate(self, x, y):
        # set up layers
        prev_layer = self.LAYERS[0] = x
        for i in range(self._num_of_weights):
            current_layer = self.forward_layer(prev_layer, 
                                               self.WEIGHT_DATA[i],
                                               self.BIAS_DATA[i], 
                                               self.LAYER_FUNC[i])
            self.LAYERS[i+1] = current_layer
            prev_layer = current_layer
        last_layer = current_layer
        error = loss_absolute(y, last_layer)
        total_error = np.sum(abs(error))
        return total_error

# %% [markdown]
# Ok! Let's test out our network using the sigmoid activation function!

# %%
# setup number of inputs/outputs for the given dataset
i_input = len(x_train[0])
i_out = len(y_train[0])

# define our layers
# (in size, out size, activation function)
layers = ((i_input, 32, sigmoid),
          (32, 16, sigmoid),
          (16, i_out, sigmoid))

# define how many training epochs
train_epochs = 1000

# define the training batch size
batch_size = 64

# set our alpha (or learning rate)
alpha = 0.001

nn = NNN(i_input, layers, i_out, alpha)

print('Training')
loss_per_epoch_bgd = nn.fit(x_train, y_train, train_epochs)

total_loss = nn.evaluate(x_test, y_test)
print('Total loss after training: {}'.format(total_loss))
# Out:
# Training
# --------------------------------
# loop: 0
# --------------------------------
# Guess (rounded):
# [0.438 0.933 0.783]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 100
# --------------------------------
# Guess (rounded):
# [0.238 0.335 0.403]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 200
# --------------------------------
# Guess (rounded):
# [0.226 0.34  0.437]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 300
# --------------------------------
# Guess (rounded):
# [0.227 0.342 0.539]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 400
# --------------------------------
# Guess (rounded):
# [0.207 0.342 0.414]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 500
# --------------------------------
# Guess (rounded):
# [0.231 0.314 0.298]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 600
# --------------------------------
# Guess (rounded):
# [0.624 0.182 0.075]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 700
# --------------------------------
# Guess (rounded):
# [0.17  0.33  0.287]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 800
# --------------------------------
# Guess (rounded):
# [0.065 0.445 0.641]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 900
# --------------------------------
# Guess (rounded):
# [0.842 0.127 0.031]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# Total loss after training: 23.14041059807694

# %% [markdown]
# Awesome! we just built a simple neural network! Now we know it works, lets start experimenting with some of the common improvements we can make to this toy network.

# %% [markdown]
# Lets train the same network however, this time let's use momentum batch descent rather than vanilla batch descent! Momentum batch descent will allow us to pass over some of the local minima on the way down to the global minima (aka the point where loss is at its lowest, meaning accuracy is at its highest).

# %%
# setup number of inputs/outputs for the given dataset
i_input = len(x_train[0])
i_out = len(y_train[0])

# define our layers
# (in size, out size, activation function)
layers = ((i_input, 32, sigmoid),
          (32, 16, sigmoid),
          (16, i_out, sigmoid))

# define how many training epochs
train_epochs = 1000

# define the training batch size
batch_size = 64

# set our alpha (or learning rate)
alpha = 0.001

# set our momentum options
mu = 0.9
momentum = True

nn = NNN(i_input, layers, i_out, alpha, mu, momentum)

print('Training with momentum')
loss_per_epoch_momentum = nn.fit(x_train, y_train, train_epochs)

total_loss = nn.evaluate(x_test, y_test)
print('Total loss after training with momentum: {}'.format(total_loss))
# Out:
# Training with momentum
# --------------------------------
# loop: 0
# --------------------------------
# Guess (rounded):
# [0.887 0.608 0.631]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 100
# --------------------------------
# Guess (rounded):
# [0.294 0.313 0.414]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 200
# --------------------------------
# Guess (rounded):
# [0.259 0.325 0.422]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 300
# --------------------------------
# Guess (rounded):
# [0.525 0.263 0.181]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 400
# --------------------------------
# Guess (rounded):
# [0.658 0.202 0.106]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 500
# --------------------------------
# Guess (rounded):
# [0.127 0.36  0.461]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 600
# --------------------------------
# Guess (rounded):
# [0.059 0.415 0.585]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 700
# --------------------------------
# Guess (rounded):
# [0.923 0.065 0.014]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 800
# --------------------------------
# Guess (rounded):
# [0.026 0.452 0.683]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 900
# --------------------------------
# Guess (rounded):
# [0.025 0.431 0.655]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# Total loss after training with momentum: 22.35087482586897

# %% [markdown]
# By using momentum we are starting to see training efficiency improve already! Let's graph the loss per epoch for each. To do this we are going to need a new function! lets define a function to graph our results!

# %%
def graph_loss(losses, epochs, names=None):
    x = [x for x in range(epochs)]
    plt.xlabel = 'Epochs'
    plt.ylabel = 'error'
    plot_args = []
    for i, y in enumerate(losses):
        if names:
            plt.plot(x, y, label=names[i])
        else:
            plt.plot(x, y)
    plt.legend()
    plt.show()

# %% [markdown]
# Ok! Let's compare the results!

# %%
print('Graph of Batch Gradient Descent (and with momentum) loss per epoch')
names = ['BGD', 'BGD+Momentum']
losses = [loss_per_epoch_bgd, loss_per_epoch_momentum]
graph_loss(losses, train_epochs, names)
# Out:
# Graph of Batch Gradient Descent (and with momentum) loss per epoch

# %% [markdown]
# Nice! We can see that momentum helps us train the network. Next lets try our momentum BGD with some different Activation Functions! First lets the using a Tanh rather than a Sigmoid! Sigmoids saturate very fast and do not cross the y axis at the origin, tanhs on the other hand do this. This should help make the network train faster since out weight values are all centered around 0 and have a range between -1 and 1. These similarities should mean the network can train and learn faster!

# %%
# setup number of inputs/outputs for the given dataset
i_input = len(x_train[0])
i_out = len(y_train[0])

# define our layers
# (in size, out size, activation function)
layers = ((i_input, 32, tanh),
          (32, 16, tanh),
          (16, i_out, sigmoid))

# define how many training epochs
train_epochs = 1000

# define the training batch size
batch_size = 64

# set our alpha (or learning rate)
alpha = 0.001

# set our momentum options
mu = 0.9
momentum = True

nn = NNN(i_input, layers, i_out, alpha, mu, momentum)

print('Training with momentum and tanh')
loss_per_epoch_mtanh = nn.fit(x_train, y_train, train_epochs)

total_loss = nn.evaluate(x_test, y_test)
print('Total loss after training with momentum and tanh: {}'.format(total_loss))
# Out:
# Training with momentum and tanh
# --------------------------------
# loop: 0
# --------------------------------
# Guess (rounded):
# [0.227 0.111 0.938]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 100
# --------------------------------
# Guess (rounded):
# [0.89  0.171 0.07 ]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 200
# --------------------------------
# Guess (rounded):
# [0.949 0.097 0.024]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 300
# --------------------------------
# Guess (rounded):
# [0.96  0.052 0.013]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 400
# --------------------------------
# Guess (rounded):
# [0.013 0.88  0.081]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 500
# --------------------------------
# Guess (rounded):
# [0.026 0.952 0.015]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 600
# --------------------------------
# Guess (rounded):
# [0.003 0.274 0.708]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 700
# --------------------------------
# Guess (rounded):
# [0.978 0.02  0.004]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 800
# --------------------------------
# Guess (rounded):
# [0.964 0.045 0.003]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 900
# --------------------------------
# Guess (rounded):
# [0.002 0.044 0.952]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# Total loss after training with momentum and tanh: 7.287673714195554

# %%
print('Graph of Batch Gradient Descent, momentum and tanh loss per epoch')
names.append('BGD+Momentum+tanh')
losses.append(loss_per_epoch_mtanh)
graph_loss(losses, train_epochs, names)
# Out:
# Graph of Batch Gradient Descent, momentum and tanh loss per epoch

# %% [markdown]
# Wow! This network is starting to train really well! Lets see if we can use other Activation Functions to get even better results! Time to try the leaky Rectified Linear Unit (leaky ReLU).

# %%
# setup number of inputs/outputs for the given dataset
i_input = len(x_train[0])
i_out = len(y_train[0])

# define our layers
# (in size, out size, activation function)
layers = ((i_input, 32, leaky_ReLU),
          (32, 16, leaky_ReLU),
          (16, i_out, sigmoid))

# define how many training epochs
train_epochs = 1000

# define the training batch size
batch_size = 64

# set our alpha (or learning rate)
alpha = 0.001

# set our momentum options
mu = 0.9
momentum = True

nn = NNN(i_input, layers, i_out, alpha, mu, momentum)

print('Training with momentum and leaky ReLU')
loss_per_epoch_mlrelu = nn.fit(x_train, y_train, train_epochs)

total_loss = nn.evaluate(x_test, y_test)
print('Total loss after training with momentum and leaky ReLU: {}'.format(total_loss))
# Out:
# Training with momentum and leaky ReLU
# --------------------------------
# loop: 0
# --------------------------------
# Guess (rounded):
# [1.    0.709 0.493]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 100
# --------------------------------
# Guess (rounded):
# [0.97  0.001 0.011]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 200
# --------------------------------
# Guess (rounded):
# [0.001 0.411 0.382]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 300
# --------------------------------
# Guess (rounded):
# [0.    0.142 0.991]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 400
# --------------------------------
# Guess (rounded):
# [0.    0.027 0.992]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 500
# --------------------------------
# Guess (rounded):
# [0.    0.22  0.653]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 600
# --------------------------------
# Guess (rounded):
# [0.    0.065 0.99 ]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 700
# --------------------------------
# Guess (rounded):
# [0.01  0.921 0.034]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 800
# --------------------------------
# Guess (rounded):
# [0.    0.002 0.999]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 900
# --------------------------------
# Guess (rounded):
# [0.    0.032 0.996]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# Total loss after training with momentum and leaky ReLU: 5.388502622229407

# %%
print('Graph of Batch Gradient Descent, momentum, tanh, leaky ReLU loss per epoch')
names.append('BGD+Momentum+leaky ReLU')
losses.append(loss_per_epoch_mlrelu)
graph_loss(losses, train_epochs, names)
# Out:
# Graph of Batch Gradient Descent, momentum, tanh, leaky ReLU loss per epoch

# %% [markdown]
# the network does seem to be training quite well! Now let's see if the slightly more computationally intensive Exponential Linear Unit will give us better results!

# %%
# setup number of inputs/outputs for the given dataset
i_input = len(x_train[0])
i_out = len(y_train[0])

# define our layers
# (in size, out size, activation function)
layers = ((i_input, 32, ELU),
          (32, 16, ELU),
          (16, i_out, sigmoid))

# define how many training epochs
train_epochs = 1000

# define the training batch size
batch_size = 64

# set our alpha (or learning rate)
alpha = 0.001

# set our momentum options
mu = 0.9
momentum = True

nn = NNN(i_input, layers, i_out, alpha, mu, momentum)

print('Training with momentum and ELU')
loss_per_epoch_melu = nn.fit(x_train, y_train, train_epochs)

total_loss = nn.evaluate(x_test, y_test)
print('Total loss after training with momentum and ELU: {}'.format(total_loss))
# Out:
# Training with momentum and ELU
# --------------------------------
# loop: 0
# --------------------------------
# Guess (rounded):
# [0.925 0.024 0.33 ]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 100
# --------------------------------
# Guess (rounded):
# [0.078 0.363 0.521]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 200
# --------------------------------
# Guess (rounded):
# [0.82  0.162 0.054]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 300
# --------------------------------
# Guess (rounded):
# [0.013 0.419 0.603]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 400
# --------------------------------
# Guess (rounded):
# [0.008 0.467 0.71 ]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 500
# --------------------------------
# Guess (rounded):
# [0.036 0.391 0.305]
# Actual:
# [0. 1. 0.]
# --------------------------------
#
# --------------------------------
# loop: 600
# --------------------------------
# Guess (rounded):
# [0.972 0.111 0.001]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# --------------------------------
# loop: 700
# --------------------------------
# Guess (rounded):
# [0.006 0.421 0.613]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 800
# --------------------------------
# Guess (rounded):
# [0.002 0.457 0.839]
# Actual:
# [0. 0. 1.]
# --------------------------------
#
# --------------------------------
# loop: 900
# --------------------------------
# Guess (rounded):
# [0.976 0.131 0.   ]
# Actual:
# [1. 0. 0.]
# --------------------------------
#
# Total loss after training with momentum and ELU: 17.124011959168026

# %%
print('Graph of Batch Gradient Descent, momentum, tanh, leaky ReLU and ELU loss per epoch')
names.append('BGD+Momentum+ELU')
losses.append(loss_per_epoch_melu)
graph_loss(losses, train_epochs, names)
# Out:
# Graph of Batch Gradient Descent, momentum, tanh, leaky ReLU and ELU loss per epoch
